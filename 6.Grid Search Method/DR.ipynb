# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("insurance_pre.csv")
print(dataset)
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
print(dataset)
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent_input=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
print(independent_input)
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent_output=dataset[["charges"]]
print(dependent_output)
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent_input,dependent_output,test_size=1/3,random_state=0)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#       age    bmi  children  sex_male  smoker_yes
# 482    18  31.35         0     False       False
# 338    50  32.30         1      True        True
# 356    46  43.89         3      True       False
# 869    25  24.30         3     False       False
# 182    22  19.95         3      True       False
# ...   ...    ...       ...       ...         ...
# 763    27  26.03         0      True       False
# 835    42  35.97         2      True       False
# 1216   40  25.08         0      True       False
# 559    19  35.53         0      True       False
# 684    33  18.50         1     False       False
#
# [892 rows x 5 columns]
#       age     bmi  children  sex_male  smoker_yes
# 578    52  30.200         1      True       False
# 610    47  29.370         1     False       False
# 569    48  40.565         2      True        True
# 1034   61  38.380         0      True       False
# 198    51  18.050         0     False       False
# ...   ...     ...       ...       ...         ...
# 261    20  26.840         1     False        True
# 1271   25  34.485         0     False       False
# 1313   19  34.700         2     False        True
# 2      28  33.000         3      True       False
# 405    52  38.380         2     False       False
#
# [446 rows x 5 columns]
#          charges
# 482    1622.1885
# 338   41919.0970
# 356    8944.1151
# 869    4391.6520
# 182    4005.4225
# ...          ...
# 763    3070.8087
# 835    7160.3303
# 1216   5415.6612
# 559    1646.4297
# 684    4766.0220
#
# [892 rows x 1 columns]
#           charges
# 578    9724.53000
# 610    8547.69130
# 569   45702.02235
# 1034  12950.07120
# 198    9644.25250
# ...           ...
# 261   17085.26760
# 1271   3021.80915
# 1313  36397.57600
# 2      4449.46200
# 405   11396.90020
#
# [446 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
parameter_grid={'criterion':['squared_error', 'absolute_error','friedman_mse'],
               'max_features':[None,'sqrt','log2'],
               'splitter':['best','random']}
grid=GridSearchCV(DecisionTreeRegressor(), parameter_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
print("The R_score value for best model {}".format(grid.best_params_))
# Out:
# The R_score value for best model {'criterion': 'squared_error', 'max_features': None, 'splitter': 'best'}

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005558      0.000633         0.002308        0.000253
# 1        0.003603      0.000557         0.002198        0.000321
# 2        0.003887      0.000469         0.002063        0.000484
# 3        0.016238      0.017227         0.003301        0.002911
# 4        0.010204      0.010995         0.002628        0.003176
# 5        0.004033      0.003918         0.002427        0.003938
# 6        0.027799      0.014366         0.002260        0.000695
# 7        0.029391      0.011463         0.003315        0.003474
# 8        0.015792      0.007430         0.001632        0.002215
# 9        0.019138      0.011235         0.002183        0.002675
# 10       0.013523      0.003088         0.002261        0.002670
# 11       0.010848      0.002261         0.003514        0.001360
# 12       0.005693      0.001862         0.002826        0.002207
# 13       0.003201      0.000655         0.001357        0.001184
# 14       0.005737      0.002135         0.003483        0.001762
# 15       0.004399      0.002123         0.001550        0.001014
# 16       0.003874      0.000785         0.002416        0.000868
# 17       0.002759      0.000532         0.002250        0.000268
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               None           best
# 7   absolute_error               None         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               None           best
# 13    friedman_mse               None         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.680600
# 1   {'criterion': 'squared_error', 'max_features':...           0.581550
# 2   {'criterion': 'squared_error', 'max_features':...           0.623342
# 3   {'criterion': 'squared_error', 'max_features':...           0.424294
# 4   {'criterion': 'squared_error', 'max_features':...           0.395092
# 5   {'criterion': 'squared_error', 'max_features':...           0.656389
# 6   {'criterion': 'absolute_error', 'max_features'...           0.632071
# 7   {'criterion': 'absolute_error', 'max_features'...           0.590446
# 8   {'criterion': 'absolute_error', 'max_features'...           0.612419
# 9   {'criterion': 'absolute_error', 'max_features'...           0.584722
# 10  {'criterion': 'absolute_error', 'max_features'...           0.598809
# 11  {'criterion': 'absolute_error', 'max_features'...           0.589970
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.703963
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.646641
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.666881
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.522215
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.563745
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.657267
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.521556           0.782493           0.592868
# 1            0.637843           0.669841           0.611199
# 2            0.502090           0.630376           0.717396
# 3            0.555119           0.646639           0.569064
# 4            0.264641           0.598132           0.638841
# 5            0.333632           0.549904           0.441705
# 6            0.571902           0.689209           0.578620
# 7            0.639931           0.691469           0.633609
# 8            0.389697           0.572222           0.405163
# 9            0.640678           0.527314           0.314298
# 10           0.662327           0.700548           0.687587
# 11           0.575153           0.647157           0.447779
# 12           0.493920           0.729812           0.593688
# 13           0.584228           0.675707           0.550163
# 14           0.570239           0.432458           0.522682
# 15           0.519445           0.719397           0.582401
# 16           0.524926           0.684406           0.537729
# 17           0.488889           0.655940           0.589516
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.658016         0.647107        0.087493                1
# 1            0.591374         0.618361        0.032138                6
# 2            0.590528         0.612746        0.069445                7
# 3            0.609209         0.560865        0.075427               14
# 4            0.320854         0.443512        0.149295               18
# 5            0.555113         0.507348        0.110265               17
# 6            0.631881         0.620737        0.042661                4
# 7            0.606369         0.632365        0.034598                3
# 8            0.644753         0.524851        0.106659               16
# 9            0.618089         0.537020        0.117722               15
# 10           0.446540         0.619162        0.093147                5
# 11           0.676385         0.587289        0.078917               11
# 12           0.662900         0.636856        0.084990                2
# 13           0.563794         0.604106        0.048715                8
# 14           0.632912         0.565035        0.082919               12
# 15           0.639492         0.596590        0.075639                9
# 16           0.502121         0.562586        0.064084               13
# 17           0.550943         0.588511        0.064204               10

# %%
age_input=float(input("Age"))
bmi_input=float(input("BMI"))
children_input=float(input("children"))
sex_male_input=int(input("Sex male 0 or 1"))
smoker_yes_input=int(input("smoker yes 0 or 1"))
# Out:
# Age 20
# BMI 35
# children 2
# Sex male 0 or 1 0
# smoker yes 0 or 1 1

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future prediction {}".format(Future_prediction))
# Out:
# Future prediction [63770.42801]

# %%
import pickle
filename="Finalised_grid_search.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("Finalised_grid_search.sav",'rb'))

# %%
result=loaded_model.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print(result)
# Out:
# [63770.42801]
