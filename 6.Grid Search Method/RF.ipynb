# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("insurance_pre.csv")
print(dataset)
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
print(dataset)
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent_input=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
print(independent_input)
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent_output=dataset[["charges"]]
print(dependent_output)
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent_input,dependent_output,test_size=1/3,random_state=0)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#       age    bmi  children  sex_male  smoker_yes
# 482    18  31.35         0     False       False
# 338    50  32.30         1      True        True
# 356    46  43.89         3      True       False
# 869    25  24.30         3     False       False
# 182    22  19.95         3      True       False
# ...   ...    ...       ...       ...         ...
# 763    27  26.03         0      True       False
# 835    42  35.97         2      True       False
# 1216   40  25.08         0      True       False
# 559    19  35.53         0      True       False
# 684    33  18.50         1     False       False
#
# [892 rows x 5 columns]
#       age     bmi  children  sex_male  smoker_yes
# 578    52  30.200         1      True       False
# 610    47  29.370         1     False       False
# 569    48  40.565         2      True        True
# 1034   61  38.380         0      True       False
# 198    51  18.050         0     False       False
# ...   ...     ...       ...       ...         ...
# 261    20  26.840         1     False        True
# 1271   25  34.485         0     False       False
# 1313   19  34.700         2     False        True
# 2      28  33.000         3      True       False
# 405    52  38.380         2     False       False
#
# [446 rows x 5 columns]
#          charges
# 482    1622.1885
# 338   41919.0970
# 356    8944.1151
# 869    4391.6520
# 182    4005.4225
# ...          ...
# 763    3070.8087
# 835    7160.3303
# 1216   5415.6612
# 559    1646.4297
# 684    4766.0220
#
# [892 rows x 1 columns]
#           charges
# 578    9724.53000
# 610    8547.69130
# 569   45702.02235
# 1034  12950.07120
# 198    9644.25250
# ...           ...
# 261   17085.26760
# 1271   3021.80915
# 1313  36397.57600
# 2      4449.46200
# 405   11396.90020
#
# [446 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['squared_error', 'absolute_error'],
              'max_features': [None,'sqrt','log2'],
              'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
print("The R_score value for best model {}".format(grid.best_params_))
# Out:
# The R_score value for best model {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.042291      0.007308         0.003076        0.000399
# 1        0.353158      0.020212         0.014518        0.005888
# 2        0.033267      0.005105         0.001802        0.001602
# 3        0.257042      0.010984         0.012748        0.002460
# 4        0.030262      0.001375         0.000901        0.001802
# 5        0.259518      0.007287         0.013023        0.004137
# 6        0.125560      0.003111         0.000000        0.000000
# 7        1.233439      0.030084         0.007683        0.002441
# 8        0.073979      0.004746         0.004188        0.005206
# 9        0.721522      0.001997         0.009021        0.000908
# 10       0.070809      0.001647         0.000601        0.001201
# 11       0.709656      0.016756         0.011255        0.004618
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  10
# 1    squared_error               None                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6   absolute_error               None                  10
# 7   absolute_error               None                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.789047
# 1   {'criterion': 'squared_error', 'max_features':...           0.800956
# 2   {'criterion': 'squared_error', 'max_features':...           0.785589
# 3   {'criterion': 'squared_error', 'max_features':...           0.804524
# 4   {'criterion': 'squared_error', 'max_features':...           0.794379
# 5   {'criterion': 'squared_error', 'max_features':...           0.801679
# 6   {'criterion': 'absolute_error', 'max_features'...           0.774839
# 7   {'criterion': 'absolute_error', 'max_features'...           0.785149
# 8   {'criterion': 'absolute_error', 'max_features'...           0.791294
# 9   {'criterion': 'absolute_error', 'max_features'...           0.798422
# 10  {'criterion': 'absolute_error', 'max_features'...           0.791988
# 11  {'criterion': 'absolute_error', 'max_features'...           0.799630
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.744399           0.834395           0.809986
# 1            0.760018           0.837011           0.808690
# 2            0.753510           0.832403           0.794325
# 3            0.767802           0.834137           0.832631
# 4            0.745445           0.815983           0.812437
# 5            0.769595           0.841765           0.827346
# 6            0.751238           0.804695           0.797376
# 7            0.778348           0.815286           0.804651
# 8            0.751115           0.834670           0.824441
# 9            0.775093           0.836566           0.828370
# 10           0.753373           0.820241           0.793115
# 11           0.772129           0.833194           0.823701
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.746567         0.784879        0.035231                8
# 1            0.761082         0.793551        0.029501                5
# 2            0.747920         0.782749        0.030579                9
# 3            0.759543         0.799727        0.031381                3
# 4            0.744667         0.782582        0.031505               10
# 5            0.768355         0.801748        0.029683                1
# 6            0.741532         0.773936        0.024745               12
# 7            0.758662         0.788419        0.019914                6
# 8            0.734184         0.787141        0.039420                7
# 9            0.762430         0.800176        0.028900                2
# 10           0.718662         0.775476        0.035508               11
# 11           0.757150         0.797161        0.029108                4

# %%
age_input=float(input("Age"))
bmi_input=float(input("BMI"))
children_input=float(input("children"))
sex_male_input=int(input("Sex male 0 or 1"))
smoker_yes_input=int(input("smoker yes 0 or 1"))
# Out:
# Age 20
# BMI 35
# children 2
# Sex male 0 or 1 0
# smoker yes 0 or 1 1

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future prediction {}".format(Future_prediction))
# Out:
# Future prediction [47551.7064428]

# %%
import pickle
filename="Finalised_grid_search.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("Finalised_grid_search.sav",'rb'))

# %%
result=loaded_model.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print(result)
# Out:
# [47551.7064428]
