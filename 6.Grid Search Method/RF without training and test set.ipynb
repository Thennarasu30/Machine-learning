# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("insurance_pre.csv")
print(dataset)
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
print(dataset)
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
independent_input=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
print(independent_input)
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent_output=dataset[["charges"]]
print(dependent_output)
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['squared_error', 'absolute_error'],
              'max_features': [None,'sqrt','log2'],
              'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(independent_input,dependent_output)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
print("The R_score value for best model {}".format(grid.best_params_))
# Out:
# The R_score value for best model {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)
print(table)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.051851      0.001935         0.005293        0.003834
# 1        0.422613      0.004817         0.014136        0.005596
# 2        0.036889      0.005959         0.002020        0.002492
# 3        0.306686      0.004154         0.011638        0.002733
# 4        0.037625      0.005159         0.005211        0.004596
# 5        0.304849      0.006747         0.014650        0.004874
# 6        0.207194      0.004718         0.006687        0.003836
# 7        2.035569      0.020292         0.013177        0.005643
# 8        0.118377      0.004160         0.003803        0.004013
# 9        1.128180      0.028338         0.011508        0.002907
# 10       0.125462      0.009754         0.004713        0.001371
# 11       1.072063      0.043665         0.019195        0.008172
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  10
# 1    squared_error               None                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6   absolute_error               None                  10
# 7   absolute_error               None                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.832307
# 1   {'criterion': 'squared_error', 'max_features':...           0.843829
# 2   {'criterion': 'squared_error', 'max_features':...           0.832083
# 3   {'criterion': 'squared_error', 'max_features':...           0.855132
# 4   {'criterion': 'squared_error', 'max_features':...           0.847589
# 5   {'criterion': 'squared_error', 'max_features':...           0.856912
# 6   {'criterion': 'absolute_error', 'max_features'...           0.810319
# 7   {'criterion': 'absolute_error', 'max_features'...           0.840638
# 8   {'criterion': 'absolute_error', 'max_features'...           0.820227
# 9   {'criterion': 'absolute_error', 'max_features'...           0.858047
# 10  {'criterion': 'absolute_error', 'max_features'...           0.848966
# 11  {'criterion': 'absolute_error', 'max_features'...           0.855119
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.760046           0.857231           0.809896
# 1            0.773034           0.853163           0.821244
# 2            0.771620           0.832319           0.817367
# 3            0.779809           0.855879           0.829864
# 4            0.744287           0.841604           0.803175
# 5            0.780842           0.859510           0.828402
# 6            0.759693           0.834903           0.815773
# 7            0.769074           0.851871           0.828323
# 8            0.758774           0.844917           0.826154
# 9            0.783381           0.857715           0.830473
# 10           0.764763           0.844168           0.811868
# 11           0.781551           0.854288           0.826703
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.820601         0.816016        0.032110                9
# 1            0.833915         0.825037        0.028078                5
# 2            0.820869         0.814852        0.022421               10
# 3            0.841253         0.832387        0.027995                4
# 4            0.801087         0.807549        0.036948               12
# 5            0.839423         0.833018        0.028487                2
# 6            0.818243         0.807786        0.025408               11
# 7            0.834191         0.824819        0.028947                6
# 8            0.835084         0.817031        0.030301                8
# 9            0.844235         0.834770        0.027630                1
# 10           0.823066         0.818566        0.030131                7
# 11           0.846108         0.832754        0.027570                3

# %%
age_input=float(input("Age"))
bmi_input=float(input("BMI"))
children_input=float(input("children"))
sex_male_input=int(input("Sex male 0 or 1"))
smoker_yes_input=int(input("smoker yes 0 or 1"))
# Out:
# Age 20
# BMI 35
# children 2
# Sex male 0 or 1 0
# smoker yes 0 or 1 1

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future prediction {}".format(Future_prediction))
# Out:
# Future prediction [35600.7649151]
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename="Finalised_grid_search.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("Finalised_grid_search.sav",'rb'))

# %%
result=loaded_model.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print(result)
# Out:
# [35600.7649151]
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
